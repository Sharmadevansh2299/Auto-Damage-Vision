# %%
# Week 5 – End-to-End Vehicle Damage Severity Pipeline
# Objective: Integrate YOLOv8 detection + severity classification

# %%
# Step 1: Imports

import cv2
import numpy as np
import matplotlib.pyplot as plt
from ultralytics import YOLO
import tensorflow as tf

# %%
# Step 2: Load Models

# TODO: Load YOLOv8 detector
yolo_model = None

# TODO: Load trained severity classifier
severity_model = None

# %%
# Step 3: Load Image

IMAGE_PATH = "test_vehicle.jpg"
image = cv2.imread(IMAGE_PATH)

# %%
# Step 4: Detect Damage Regions

# TODO:
# - Run YOLOv8 inference
# - Extract bounding boxes

boxes = []

# %%
# Step 5: Predict Severity

severity_labels = ["Minor", "Moderate", "Severe"]

# TODO:
# - Crop each box
# - Resize
# - Predict severity
# - Draw box + label

# %%
# Step 6: Visualization

plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.axis("off")

# %%
# Reflection
# - What happens when detection is wrong?
# - Why is modular design useful here?
